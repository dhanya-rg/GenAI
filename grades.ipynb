# %%
# Student data
# This notebook analysis student details
# Out:
# Running cells with 'c:\Users\ganeshswarna\AppData\Local\Programs\Python\Python39\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/ganeshswarna/AppData/Local/Programs/Python/Python39/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
data = [50,50,47,97,44];
print(type(data));
import numpy as np;
grades = np.array(data);
print(grades);
print(data *2);
print(grades*2);
print(grades.mean());
# Out:
# <class 'list'>
# [50 50 47 97 44]
# [50, 50, 47, 97, 44, 50, 50, 47, 97, 44]
# [100 100  94 194  88]
# 57.6
